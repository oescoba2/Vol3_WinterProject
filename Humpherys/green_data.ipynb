# %%
import pandas as pd

raw_data = pd.read_csv('ukr-ndvi-adm2-full.csv', skiprows=1)
print(raw_data.head())
print(raw_data.columns)

regions = raw_data['#adm2+code'].unique()
print(regions)

region1 = raw_data[raw_data['#adm2+code']  == "UA6312"].iloc[:817]
# Out:
#         #date  #adm2+id #adm2+code  #indicator+n_pixels+num  \
# 0  2002-07-01   1013455     UA4802                     65.0
# 1  2002-07-11   1013455     UA4802                     65.0
# 2  2002-07-21   1013455     UA4802                     65.0
# 3  2002-08-01   1013455     UA4802                     65.0
# 4  2002-08-11   1013455     UA4802                     65.0
#
#    #indicator+vim+num  #indicator+vim_avg+num  #indicator+viq+pct
# 0              0.5062                  0.6360             81.0741
# 1              0.5160                  0.6318             83.0078
# 2              0.5278                  0.6157             86.7884
# 3              0.5379                  0.5908             91.7318
# 4              0.5425                  0.5611             96.9463
# Index(['#date', '#adm2+id', '#adm2+code', '#indicator+n_pixels+num',
#        '#indicator+vim+num', '#indicator+vim_avg+num', '#indicator+viq+pct'],
#       dtype='object')
# ['UA4802' 'UA6802' 'UA0512' 'UA4606' 'UA2304' 'UA7108' 'UA5308' 'UA7102'
#  'UA6306' 'UA7306' 'UA0110' 'UA6312' 'UA1408' 'UA6510' 'UA6804' 'UA5304'
#  'UA2606' 'UA7304' 'UA6508' 'UA6506' 'UA7106' 'UA3502' 'UA1406' 'UA2608'
#  'UA2310' 'UA6106' 'UA5110' 'UA0502' 'UA2112' 'UA5102' 'UA6504' 'UA2604'
#  'UA6806' 'UA6304' 'UA5108' 'UA3212' 'UA1802' 'UA0114' 'UA5302' 'UA6102'
#  'UA4412' 'UA1204' 'UA4808' 'UA1206' 'UA0510' 'UA6308' 'UA0504' 'UA1804'
#  'UA5112' 'UA6310' 'UA4408' 'UA6302' 'UA3504' 'UA4402' 'UA0118' 'UA2610'
#  'UA1412' 'UA6104' 'UA0112' 'UA6502' 'UA5104' 'UA0104' 'UA4410' 'UA3202'
#  'UA4414' 'UA1410' 'UA4806' 'UA2102' 'UA0120' 'UA5106' 'UA1416' 'UA0102'
#  'UA1402' 'UA0506' 'UA2302' 'UA4602' 'UA1202' 'UA3506' 'UA4804' 'UA4404'
#  'UA7104' 'UA0106' 'UA3214' 'UA3204' 'UA4604' 'UA0508' 'UA0108' 'UA6314'
#  'UA4406' 'UA1212' 'UA1214' 'UA2108' 'UA3508' 'UA4608' 'UA1208' 'UA2110'
#  'UA4610' 'UA0116' 'UA5306' 'UA2104' 'UA4416' 'UA2306' 'UA5114' 'UA4614'
#  'UA2612' 'UA7302' 'UA2308' 'UA2602' 'UA1404' 'UA1210' 'UA1414' 'UA2106']

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(30, 5))
plt.plot(region1['#date'], region1['#indicator+vim+num'])
plt.show()

# %%
plt.figure(figsize=(30, 5))
plt.plot(region1['#date'], region1['#indicator+viq+pct'])
plt.show()

# %%
plt.figure(figsize=(30, 5))
plt.plot(region1['#date'], region1['#indicator+vim_avg+num'])
plt.show()

# %%
region1.to_csv('uk_green.csv')
